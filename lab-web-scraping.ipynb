# %% [markdown]
# # Lab | Web Scraping

# %% [markdown]
# Welcome to the IMDb Web Scraping Adventure Lab!
#
# **Objective**
#
# In this lab, we will embark on a mission to unearth valuable insights from the vast sea of data available on IMDb, one of the largest online databases of movie, TV, and celebrity information. As budding data scientists and business analysts, you have been tasked to scrape a specific subset of data from IMDb to assist film production companies in understanding the landscape of highly-rated movies in a defined time period. Your insights will potentially influence the making of the next netflix movie!
#
# **Background**
#
# In a world where data has become the new currency, businesses are leveraging big data to make informed decisions that drive success and profitability. The entertainment industry, being no exception, utilizes data analytics to comprehend market trends, audience preferences, and the performance of films based on various parameters such as director, genre, stars involved, etc. IMDb stands as a goldmine of such data, offering intricate details of almost every movie ever made.
#
# **Task**
#
# Your task is to create a Python script using `BeautifulSoup` and `pandas` to scrape IMDb movie data based on user ratings and release dates. This script should be able to filter movies with ratings above a certain threshold and within a specified date range.
#
# **Expected Outcome**
#
# - A function named `scrape_imdb` that takes four parameters: `title_type`,`user_rating`, `start_date`, and `end_date`.
# - The function should return a DataFrame with the following columns:
#   - **Movie Nr**: The number representing the movie’s position in the list.
#   - **Title**: The title of the movie.
#   - **Year**: The year the movie was released.
#   - **Rating**: The IMDb rating of the movie.
#   - **Runtime (min)**: The duration of the movie in minutes.
#   - **Genre**: The genre of the movie.
#   - **Description**: A brief description of the movie.
#   - **Director**: The director of the movie.
#   - **Stars**: The main stars of the movie.
#   - **Votes**: The number of votes the movie received.
#   - **Gross ($M)**: The gross earnings of the movie in millions of USD.
#
# You will execute this script to scrape data for movies with the Title Type `Feature Film` that have a user rating of `7.5 and above` and were released between `January 1, 1990, and December 31, 1992`.
#
# Remember to experiment with different title types, dates and ratings to ensure your code is versatile and can handle various searches effectively!
#
# **Resources**
#
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
# - [IMDb Advanced Search](https://www.imdb.com/search/title/)

# %% [markdown]
# **Hint**
#
# Your first mission is to familiarize yourself with the IMDb advanced search page. Head over to [IMDb advanced search](https://www.imdb.com/search/title/) and input the following parameters, keeping all other fields to their default values or blank:
#
# - **Title Type**: Feature film
# - **Release date**: From 1990 to 1992 (Note: You don't need to specify the day and month)
# - **User Rating**: 7.5 to -
#
# Upon searching, you'll land on a page showcasing a list of movies, each displaying vital details such as the title, release year, and crew information. Your task is to scrape this treasure trove of data.
#
# Carefully examine the resulting URL and construct your own URL to include all the necessary parameters for filtering the movies.

# %% [markdown]
# ---
#
# **Best of luck! Immerse yourself in the world of movies and may the data be with you!**

# %% [markdown]
# **Important note**:
#
# In the fast-changing online world, websites often get updates and make changes. When you try this lab, the IMDb website might be different from what we expect.
#
# If you run into problems because of these changes, like new rules or things that stop you from getting data, don't worry! Instead, get creative.
#
# You can choose another website that interests you and is good for scraping data. Websites like Wikipedia or The New York Times are good options. The main goal is still the same: get useful data and learn how to scrape it from a website that you find interesting. It's a chance to practice your web scraping skills and explore a source of information you like.

# %%
import requests

# %%
url = "https://www.allocine.fr/films/"
response = requests.get(url)

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="fr">\n<head>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n<meta name="robots" content="index,follow,max-snippet:-1" />\n<title>Les films les plus populaires - AlloCin\xc3\xa9</title>\n<meta name="keywords" content />\n<meta name="Googlebot" content="noarchive" />\n<meta name="distribution" content="global" />\n<meta name="author" content="AlloCine" />\n<meta name="country" content="France" />\n<meta name="geo.position" content="48.87078;2.30447" />\n<meta name="geo.country" content="FR" />\n<meta name="ICBM" content="48.87078;2.30447" />\n<meta name="theme-color" content="#FECC00" />\n<meta name="description" content="D\xc3\xa9couvrez tous les films les plus populaires sur AlloCin\xc3\xa9, comme :  Napol\xc3\xa9on, La Tresse, Hunger Games: la Ballade du serpent et de l\'oiseau chanteur" />\n<meta property="og:site_name" content="AlloCin\xc3\xa9" />\n<meta property="og:title" content="Les films les plus populaires sur AlloCin\xc3\xa9" />\n<meta property="og:description" content="D\xc3\xa9couvrez tous les films les plus populaires sur AlloCin\xc3\xa9" />\n<meta property="fb:app_id" content="99197768694" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:site" content="@allocine" />\n<meta name="twitter:title" content="Les films les plus populaires sur AlloCin\xc3\xa9" />\n<meta name="twitter:description" content="D\xc3\xa9couvrez tous les films les plus populaires sur AlloCin\xc3\xa9" />\n<meta name="twitter:image" content />\n<meta name="twitter:app:name:iphone" content="allocine" />\n<meta name="twitter:app:name:ipad" content="allocine" />\n<meta name="twitter:app:name:googleplay" content="allocine" />\n<meta name="twitter:app:url:iphone" content="allocine://open/" />\n<meta name="twitter:app:url:ipad" content="allocine://open/" />\n<meta name="twitter:app:url:googleplay" content="allocine://open/" />\n<meta name="twitter:app:id:iphone" content="351184863" />\n<meta name="twitter:app:id:ipad" content="351184863" />\n<meta name="twitter:app:id:googleplay" content="com.allocine.androidapp" />\n<meta name="apple-itunes-app" content="app-id=351184863, app-argument=allocine://open/">\n<meta property="fb:pages" content="107276450147" />\n<link rel="preconnect" href="https://assets.allocine.fr" />\n<link rel="preload" href="https://assets.allocine.fr/skin/font/icon/font-icon.woff2" as="font" type="font/woff2" crossorigin />\n<link rel="preload" href="https://assets.allocine.fr/skin/img/allocine/logo-main-grey.5de8867c.svg" type="image/svg+xml" as="image" />\n<link rel="preload" href="https://assets.allocine.fr/js/website/website-common.9749152e1087d67a76b5.js" as="script" />\n<link rel="preload" href="https://assets.allocine.fr/js/website/movies.8b13918b9f4709d34f90.js" as="script" />\n<link rel="preconnect" href="https://sdk.privacy-center.org/" />\n<style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\\00201c" "\\00201d" "\\002018" "\\002019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fi ...

# %%
from bs4 import BeautifulSoup 
import pandas as pd

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# Lists to store extracted data
film_names = []
release_dates = []
directors = []
descriptions = []
actors = []

genres = []

# Find all components
components = soup.find_all('div', class_='card entity-card entity-card-list cf')

for component in components:
    # Extract bicycle name
    film_name = component.find('h2').text.strip()
    film_names.append(film_name)

    date = component.find('span', class_="date").text.strip()
    release_dates.append(date)

    director = component.find("a", class_= "blue-link").text.strip()
    directors.append(director)

    description = component.find("div", class_= "content-txt").text.strip() 
    descriptions.append(description)

    actor= component.find("div", class_= "meta-body-item meta-body-actor").text.strip()
    actors.append(actor)


    genre = component.find_all(class_= "meta-body-item meta-body-info")
    genre_2 = []
    for g in str(genre).split("\n")[5:-1]:
        genre_2.append(g.split(">")[1].split("<")[0])
    genres.append(genre_2)
    


df = pd.DataFrame({
    'Film_name': film_names,
    "Dates": release_dates,
    "Directors": directors,
    "Film_description" : descriptions,
    "Actors": actors,
   "Genres": genres
})

df
# Out:
#                                             Film_name             Dates  \
# 0                                            Napoléon  22 novembre 2023
# 1                                           La Tresse  29 novembre 2023
# 2   Hunger Games: la Ballade du serpent et de l'oi...  15 novembre 2023
# 3                                       Soudain seuls   6 décembre 2023
# 4                      Wish - Asha et la bonne étoile  29 novembre 2023
# 5                                        Mars Express  22 novembre 2023
# 6                                        Perfect Days  29 novembre 2023
# 7                             Je ne suis pas un héros  22 novembre 2023
# 8                     Les Trois Mousquetaires: Milady  13 décembre 2023
# 9                                    Le Temps D’Aimer  29 novembre 2023
# 10                                      Rien à Perdre  22 novembre 2023
# 11                                              Wonka  13 décembre 2023
# 12                                         Bâtiment 5   6 décembre 2023
# 13                                Le Monde après nous   8 décembre 2023
# 14                              Le Garçon et le Héron   1 novembre 2023
#
#              Directors                                   Film_description  \
# 0         Ridley Scott  Fresque spectaculaire, Napoléon s'attache à l'...
# 1   Laetitia Colombani  Trois vies, trois femmes, trois continents. Tr...
# 2     Francis Lawrence  Le jeune Coriolanus est le dernier espoir de s...
# 3      Thomas Bidegain  En couple depuis 5 ans, Ben et Laura ont décid...
# 4           Chris Buck  Jeune fille de 17 ans à l’esprit vif, Asha vit...
# 5        Jérémie Périn  En l’an 2200, Aline Ruby, détective privée obs...
# 6          Wim Wenders  Hirayama travaille à l’entretien des toilettes...
# 7        Rudy Milstein  Louis c'est ce mec super gentil. Et dans son c...
# 8    Martin Bourboulon  Du Louvre au Palais de Buckingham, des bas-fon...
# 9    Katell Quillévéré  1947. Sur une plage, Madeleine, serveuse dans ...
# 10    Delphine Deloget  Sylvie vit à Brest avec ses deux enfants, Sofi...
# 11           Paul King  Découvrez la jeunesse de Willy Wonka, l’extrao...
# 12             Ladj Ly  Haby, jeune femme très impliquée dans la vie d...
# 13          Sam Esmail  Une famille qui rêvait d'une pause dans une lu...
# 14      Hayao Miyazaki  Après la disparition de sa mère dans un incend...
#
#                                                Actors  \
# 0   Avec\nJoaquin Phoenix,\nVanessa Kirby,\nTahar ...
# 1       Avec\nKim Raver,\nFotinì Peluso,\nMia Maelzer
# 2    Avec\nTom Blyth,\nRachel Zegler,\nPeter Dinklage
# 3            Avec\nGilles Lellouche,\nMélanie Thierry
# 4   Avec\nOcéane Demontis,\nAriana DeBose,\nLamber...
# 5   Avec\nLéa Drucker,\nMathieu Amalric,\nDaniel N...
# 6     Avec\nKoji Yakusho,\nTokio Emoto,\nArisa Nakano
# 7   Avec\nVincent Dedienne,\nGéraldine Nakache,\nC...
# 8   Avec\nFrançois Civil,\nVincent Cassel,\nRomain...
# 9   Avec\nAnaïs Demoustier,\nVincent Lacoste,\nPau...
# 10  Avec\nVirginie Efira,\nFélix Lefebvre,\nArieh ...
# 11  Avec\nTimothée Chalamet,\nCalah Lane,\nKeegan-...
# 12  Avec\nAnta Diaw,\nAlexis Manenti,\nAristote Lu...
# 13  Avec\nJulia Roberts,\nMahershala Ali,\nEthan H...
# 14  Avec\nGavril Dartevelle,\nSoma Santoki,\nPadri...
#
#                                   Genres
# 0         [Biopic, Historique, Aventure]
# 1                   [Comédie dramatique]
# 2    [Science Fiction, Action, Aventure]
# 3             [Thriller, Romance, Drame]
# 4         [Animation, Aventure, Famille]
# 5   [Animation, Science Fiction, Action]
# 6                       [Drame, Comédie]
# 7                              [Comédie]
# 8                 [Aventure, Historique]
# 9                       [Drame, Romance]
# 10                               [Drame]
# 11      [Aventure, Fantastique, Famille]
# 12                               [Drame]
# 13                     [Thriller, Drame]
# 14          [Animation, Drame, Aventure]

# %%
for g in df["Genres"][0]:
    print("////////////////")
    print(g)
# Out:
# ////////////////
# <div class="meta-body-item meta-body-info">
# <span class="date">22 novembre 2023</span>
# <span class="spacer">/</span>
# 2h 38min
# <span class="spacer">/</span>
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI3Lw==">Biopic</span>,
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE1Lw==">Historique</span>,
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>
# </div>

# %%
for g in str(df["Genres"][0]).split("\n")[5:-1]:
    print(g.split(">")[1:].split("<")[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 2
#       1 for g in str(df["Genres"][0]).split("\n")[5:-1]:
# ----> 2     print(g.split(">")[1:].split("<")[0])
#
# AttributeError: 'list' object has no attribute 'split'

# %%
for g in str(df["Genres"][0]).split("\n")[5:-1]:
    print(g.split(">")[1].split("<")[0])
# Out:
# Biopic
# Historique
# Aventure

# %%
.split('==">')

# %%
genre = soup.find_all(class_= "meta-body-item meta-body-info")
genre
# Out:
# [<div class="meta-body-item meta-body-info">
#  <span class="date">22 novembre 2023</span>
#  <span class="spacer">/</span>
#  2h 38min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI3Lw==">Biopic</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE1Lw==">Historique</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 novembre 2023</span>
#  <span class="spacer">/</span>
#  1h 59min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAyLw==">Comédie dramatique</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">15 novembre 2023</span>
#  <span class="spacer">/</span>
#  2h 38min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIxLw==">Science Fiction</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI1Lw==">Action</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">6 décembre 2023</span>
#  <span class="spacer">/</span>
#  1h 51min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIzLw==">Thriller</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI0Lw==">Romance</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 novembre 2023</span>
#  <span class="spacer">/</span>
#  1h 42min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI2Lw==">Animation</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDM2Lw==">Famille</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">22 novembre 2023</span>
#  <span class="spacer">/</span>
#  1h 25min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI2Lw==">Animation</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIxLw==">Science Fiction</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI1Lw==">Action</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 novembre 2023</span>
#  <span class="spacer">/</span>
#  2h 05min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA1Lw==">Comédie</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">22 novembre 2023</span>
#  <span class="spacer">/</span>
#  1h 41min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA1Lw==">Comédie</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">13 décembre 2023</span>
#  <span class="spacer">/</span>
#  1h 55min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE1Lw==">Historique</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">29 novembre 2023</span>
#  <span class="spacer">/</span>
#  2h 05min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI0Lw==">Romance</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">22 novembre 2023</span>
#  <span class="spacer">/</span>
#  1h 52min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">13 décembre 2023</span>
#  <span class="spacer">/</span>
#  1h 57min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDEyLw==">Fantastique</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDM2Lw==">Famille</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">6 décembre 2023</span>
#  <span class="spacer">/</span>
#  1h 40min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">8 décembre 2023</span>
#  <span class="spacer">/</span>
#  2h 18min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIzLw==">Thriller</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>
#  </div>,
#  <div class="meta-body-item meta-body-info">
#  <span class="date">1 novembre 2023</span>
#  <span class="spacer">/</span>
#  2h 03min
#  <span class="spacer">/</span>
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI2Lw==">Animation</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>,
#  <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxLw==">Aventure</span>
#  </div>]

# %%
pages = [f"https://www.allocine.fr/films/?page={pag}" for pag in range(2,10)]

from time import sleep

pages
# Out:
# ['https://www.allocine.fr/films/?page=2',
#  'https://www.allocine.fr/films/?page=3',
#  'https://www.allocine.fr/films/?page=4',
#  'https://www.allocine.fr/films/?page=5',
#  'https://www.allocine.fr/films/?page=6',
#  'https://www.allocine.fr/films/?page=7',
#  'https://www.allocine.fr/films/?page=8',
#  'https://www.allocine.fr/films/?page=9']

# %%
# def get_df_from_url(url):

    # response = requests.get(url)
    # soup = BeautifulSoup(response.content, 'html.parser')
    # df = extract_bike_info(soup)
    # return df

# %%
# dfs = [get_df_from_url(p) for p in pages]

# def extract_bike_info(soup):
#     # your code goes here
#     return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dfs = [get_df_from_url(p) for p in pages]
#
# Cell In[17], line 1, in <listcomp>(.0)
# ----> 1 dfs = [get_df_from_url(p) for p in pages]
#
# Cell In[16], line 6, in get_df_from_url(url)
#       3 response = requests.get(url)
#       5 soup = BeautifulSoup(response.content, 'html.parser')
# ----> 6 df = extract_bike_info(soup)
#       7 return df
#
# NameError: name 'extract_bike_info' is not defined

# %% [markdown]
# ## BONUS
#
# The search results span multiple pages, housing a total of 631 movies in our example with each page displaying 50 movies at most. To scrape data seamlessly from all pages, you'll need to dive deep into the structure of the URLs generated with each "Next" click.
#
# Take a close look at the following URLs:
# - First page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,
#   ```
# - Second page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=51&ref_=adv_nxt
#   ```
# - Third page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=101&ref_=adv_nxt
#   ```
#
# You should notice a pattern. There is a `start` parameter incrementing by 50 with each page, paired with a constant `ref_` parameter holding the value "adv_nxt".
#
# Modify your script so it's capable of iterating over all available pages to fetch data on all the 631 movies (631 is the total number of movies in the proposed example).

# %%
# Your solution goes here
